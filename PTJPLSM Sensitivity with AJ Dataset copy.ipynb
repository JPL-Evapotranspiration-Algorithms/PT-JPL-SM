# %%
from typing import Callable
from os import makedirs
from os.path import join
import numpy as np
import pandas as pd
from verma_net_radiation import verma_net_radiation_table
from PTJPLSM import process_PTJPLSM_table
from monte_carlo_sensitivity import perturbed_run, sensitivity_analysis, divide_absolute_by_unperturbed
import matplotlib.pyplot as plt
from scipy.stats import mstats
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %%
normalization_function = divide_absolute_by_unperturbed

# %%
input_df = pd.read_csv("calval_final_50_PTJPL_inputs.csv")
input_df = input_df[input_df.fAPARmax != 0]
input_df
# Out:
#      Unnamed: 0.1   tower      lat      lon  orbit  scene   tile  \
# 0               0  US-Ha2  42.5393 -72.1779   9254      9  18TYN
# 1               1  US-Ha2  42.5393 -72.1779  10150      9  18TYN
# 2               2  US-Ha2  42.5393 -72.1779  10352      9  18TYN
# 3               3  US-Ha2  42.5393 -72.1779  10684      7  18TYN
# 4               4  US-Ha2  42.5393 -72.1779  11069      8  18TYN
# ..            ...     ...      ...      ...    ...    ...    ...
# 247           247  US-xUK  39.0404 -95.1921  11909      6  15SUD
# 248           248  US-xUK  39.0404 -95.1921  16668      8  15SUD
# 249           249  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 250           250  US-xUK  39.0404 -95.1921  16810      8  15SUD
# 251           251  US-xUN  46.2339 -89.5373  12274      4  15TYM
#
#                 time_UTC    date_UTC  doy  ...    VISdiff    NIRdiff  \
# 0    2020-02-22 00:00:00  2020-02-22   53  ...   0.000000   0.000000
# 1    2020-04-20 00:00:00  2020-04-20  111  ...   0.000000   0.000000
# 2    2020-05-03 00:00:00  2020-05-03  124  ...   0.000000   0.000000
# 3    2020-05-24 00:00:00  2020-05-24  145  ...   3.627162   3.519072
# 4    2020-06-18 00:00:00  2020-06-18  170  ...   7.418505   8.696527
# ..                   ...         ...  ...  ...        ...        ...
# 247  2020-08-11 00:00:00  2020-08-11  224  ...  14.372975  12.682295
# 248  2021-06-14 00:00:00  2021-06-14  165  ...  32.456092  15.308895
# 249  2021-06-23 00:00:00  2021-06-23  174  ...  38.645010  27.577193
# 250  2021-06-23 00:00:00  2021-06-23  174  ...  38.645010  27.577193
# 251  2020-09-04 00:00:00  2020-09-04  248  ...   2.846623   2.261136
#
#         VISdir      NIRdir      SWout        LWin       LWout  hour_of_day  \
# 0     0.000000    0.000000   0.000000  223.482510  310.837408           19
# 1     0.000000    0.000000   0.000000  249.470817  483.042043           19
# 2     0.000000    0.000000   0.000000  293.358154  368.124775           19
# 3     0.337294    0.020315   0.662989         NaN  385.565499           19
# 4     1.935220    0.123967   2.254700  380.029433  454.438012           19
# ..         ...         ...        ...         ...         ...          ...
# 247   3.003822    0.000000   5.351180  414.848071  439.377199           17
# 248  93.412739  127.317082  27.991697         NaN  405.251251           17
# 249  80.881654   98.257540  28.021802         NaN  388.004691           17
# 250  80.881654   98.257540  28.021802  400.532814  463.095778           17
# 251   0.267030    0.001731   0.797800         NaN  339.018157           18
#
#      Topt  fAPARmax
# 0     0.0    0.5545
# 1     0.0    0.5545
# 2     0.0    0.5545
# 3     0.0    0.5545
# 4     0.0    0.5545
# ..    ...       ...
# 247   5.8    0.4664
# 248   5.8    0.4664
# 249   5.8    0.4664
# 250   5.8    0.4664
# 251   0.0    0.4592
#
# [252 rows x 80 columns]

# %%
np.nanmin(input_df.fAPARmax)
# Out:
# np.float64(0.3301)

# %%
def process_verma_PTJPLSM_table(input_df: pd.DataFrame) -> pd.DataFrame:
    return process_PTJPLSM_table(verma_net_radiation_table(input_df))

# %%
processed = process_verma_PTJPLSM_table(input_df)
processed
# Out:
# [2025-05-01 11:23:53 INFO] GEOS-5 FP working directory: /Users/halverso/data/GEOS5FP
# [2025-05-01 11:23:53 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 processed = process_verma_PTJPLSM_table(input_df)
#       2 processed
#
# Cell In[5], line 2, in process_verma_PTJPLSM_table(input_df)
#       1 def process_verma_PTJPLSM_table(input_df: pd.DataFrame) -> pd.DataFrame:
# ----> 2     return process_PTJPLSM_table(process_verma_net_radiation_table(input_df))
#
# File ~/Projects/PT-JPL-SM/PTJPLSM/process_PTJPLSM_table.py:57, in process_PTJPLSM_table(input_df)
#      54 lon = np.array(input_df.lon).astype(np.float64)
#      55 geometry = CoordinateArray(x=lon, y=lat, crs=WGS84)
# ---> 57 results = PTJPLSM(
#      58     geometry=geometry,
#      59     NDVI=NDVI,
#      60     Ta_C=Ta_C,
#      61     RH=RH,
#      62     soil_moisture=soil_moisture,
#      63     Rn_Wm2=Rn_Wm2,
#      64     Topt=Topt,
#      65     fAPARmax=fAPARmax,
#      66     G=G
#      67 )
#      69 output_df = input_df.copy()
#      71 for key, value in results.items():
#
# File ~/Projects/PT-JPL-SM/PTJPLSM/model.py:116, in PTJPLSM(NDVI, Rn_Wm2, geometry, time_UTC, hour_of_day, day_of_year, GEOS5FP_connection, ST_C, emissivity, albedo, G, Ta_C, RH, soil_moisture, field_capacity, wilting_point, Topt, fAPARmax, canopy_height_meters, delta_Pa, gamma_Pa, epsilon, beta_Pa, PT_alpha, field_capacity_scale, minimum_Topt, floor_Topt, resampling)
#     113     raise ValueError("soil moisture not given")
#     115 if field_capacity is None and geometry is not None:
# --> 116     field_capacity = load_field_capacity(geometry=geometry, resampling=resampling)
#     118 if wilting_point is None and geometry is not None:
#     119     wilting_point = load_wilting_point(geometry=geometry, resampling=resampling)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/soil_capacity_wilting/soil_capacity_wilting.py:240, in load_field_capacity(geometry, directory, resampling)
#     235 def load_field_capacity(
#     236         geometry: RasterGeometry = None,
#     237         directory: str = DEFAULT_DOWNLOAD_DIRECTORY,
#     238         resampling: str = DEFAULT_RESAMPLING) -> Raster:
#     239     soil_grids = SoilGrids(source_directory=directory, resampling=resampling)
# --> 240     field_capacity = soil_grids.FC(geometry=geometry, resampling=resampling)
#     242     return field_capacity
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/soil_capacity_wilting/soil_capacity_wilting.py:175, in SoilGrids.FC(self, geometry, resampling)
#     172 if not exists(filename):
#     173     self.download_file(URL, filename)
# --> 175 image = rt.Raster.open(
#     176     filename=filename,
#     177     geometry=geometry,
#     178     resampling=resampling
#     179 )
#     181 image = rt.where(image == 255, np.nan, image)
#     182 image.nodata = np.nan
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/rasters/raster.py:432, in Raster.open(cls, filename, nodata, remove, geometry, buffer, window, resampling, cmap, **kwargs)
#     429     buffer = 1
#     431 if window is None and target_geometry is not None:
# --> 432     window = source_geometry.window(geometry=target_geometry, buffer=buffer)
#     434 if window is not None and not isinstance(window, Window):
#     435     raise ValueError("invalid window")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/rasters/raster_grid.py:498, in RasterGrid.window(self, geometry, buffer)
#     495 from .point import Point
#     497 geometry = wrap_geometry(geometry)
# --> 498 xmin, ymin, xmax, ymax = geometry.bbox.transform(self.crs)
#     500 row_start, col_start = self.index_point(Point(xmin, ymax, crs=self.crs))
#     501 row_end, col_end = self.index_point(Point(xmax, ymin, crs=self.crs))
#
# AttributeError: 'function' object has no attribute 'transform'

# %%
plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
plt.scatter(x=processed.ST_C, y=processed.LE, color='black', s=10, zorder=5)
plt.grid(True, zorder=0)
plt.xlabel("ECOSTRESS Surface Temperature (°C)")
plt.ylabel("PT-JPL Latent Heat Flux (W/m$^2$)")
plt.title("Unperturbed Comparison\nof ECOSTRESS Surface Temperature\nto PT-JPL Latent Heat Flux")

plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to PT-JPL Latent Heat Flux.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to PT-JPL Latent Heat Flux.svg", format='svg', bbox_inches='tight')

plt.show()

# %%
input_df = pd.read_csv("calval_final_50_PTJPL_inputs.csv")

if "Ta" in input_df and "Ta_C" not in input_df:
    # input_df.rename({"Ta": "Ta_C"}, inplace=True)
    input_df["Ta_C"] = input_df["Ta"]

input_df = input_df[input_df.fAPARmax.apply(lambda fAPARmax: fAPARmax > 0.001)]
input_df = input_df[input_df.NDVI.apply(lambda NDVI: NDVI > 0.05)]

np.nanmin(input_df.ST_C), np.nanmax(input_df.ST_C)
# Out:
# (np.float64(0.89), np.float64(49.33))

# %%
len(input_df)
# Out:
# [2025-07-02 17:13:37 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 17:13:37 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# [2025-07-02 17:13:48 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 17:13:48 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
#       input_variable output_variable input_unperturbed  input_perturbation  \
# 400             ST_C              LE             28.03            7.341735
# 401             ST_C              LE             28.03            2.386350
# 402             ST_C              LE             28.03           -2.324508
# 403             ST_C              LE             28.03           -2.035399
# 404             ST_C              LE             28.03          -11.427681
# ...              ...             ...               ...                 ...
# 25095           ST_C              LE             30.71            1.754216
# 25096           ST_C              LE             30.71            4.955911
# 25097           ST_C              LE             30.71           16.146499
# 25098           ST_C              LE             30.71            9.023736
# 25099           ST_C              LE             30.71            8.534647
#
#        input_perturbation_std input_perturbed output_unperturbed  \
# 400                  0.261924       35.371735          12.288182
# 401                  0.085136        30.41635          12.288182
# 402                  0.082929       25.705492          12.288182
# 403                  0.072615       25.994601          12.288182
# 404                  0.407695       16.602319          12.288182
# ...                       ...             ...                ...
# 25095                0.057122       32.464216         179.198439
# 25096                0.161378       35.665911         179.198439
# 25097                0.525773       46.856499         179.198439
# 25098                0.293837       39.733736         179.198439
# 25099                0.277911       39.244647         179.198439
#
#       output_perturbation output_perturbation_std  output_perturbed
# 400             -0.084475                0.006874         12.203707
# 401              -0.02746                0.002235         12.260722
# 402               0.02675                0.002177         12.314932
# 403              0.023423                0.001906         12.311604
# 404              0.131522                0.010703         12.419704
# ...                   ...                     ...               ...
# 25095           -0.800775                0.004469        178.397664
# 25096           -2.262304                0.012625        176.936135
# 25097           -7.370648                0.041131        171.827791
# 25098           -4.119208                0.022987        175.079231
# 25099           -3.895946                0.021741        175.302493
#
# [13300 rows x 10 columns]

# %%
input_variable = "ST_C"
output_variable = "LE"

results = perturbed_run(
    input_df=input_df, 
    input_variable=input_variable, 
    output_variable=output_variable, 
    forward_process=process_verma_PTJPLSM_table,
    normalization_function=normalization_function
)

results

# %%
filtered_results = results.dropna()
filtered_results
# Out:
#       input_variable output_variable input_unperturbed  input_perturbation  \
# 400             ST_C              LE             28.03            7.341735
# 401             ST_C              LE             28.03            2.386350
# 402             ST_C              LE             28.03           -2.324508
# 403             ST_C              LE             28.03           -2.035399
# 404             ST_C              LE             28.03          -11.427681
# ...              ...             ...               ...                 ...
# 25095           ST_C              LE             30.71            1.754216
# 25096           ST_C              LE             30.71            4.955911
# 25097           ST_C              LE             30.71           16.146499
# 25098           ST_C              LE             30.71            9.023736
# 25099           ST_C              LE             30.71            8.534647
#
#        input_perturbation_std input_perturbed output_unperturbed  \
# 400                  0.261924       35.371735          12.288182
# 401                  0.085136        30.41635          12.288182
# 402                  0.082929       25.705492          12.288182
# 403                  0.072615       25.994601          12.288182
# 404                  0.407695       16.602319          12.288182
# ...                       ...             ...                ...
# 25095                0.057122       32.464216         179.198439
# 25096                0.161378       35.665911         179.198439
# 25097                0.525773       46.856499         179.198439
# 25098                0.293837       39.733736         179.198439
# 25099                0.277911       39.244647         179.198439
#
#       output_perturbation output_perturbation_std  output_perturbed
# 400             -0.084475                0.006874         12.203707
# 401              -0.02746                0.002235         12.260722
# 402               0.02675                0.002177         12.314932
# 403              0.023423                0.001906         12.311604
# 404              0.131522                0.010703         12.419704
# ...                   ...                     ...               ...
# 25095           -0.800775                0.004469        178.397664
# 25096           -2.262304                0.012625        176.936135
# 25097           -7.370648                0.041131        171.827791
# 25098           -4.119208                0.022987        175.079231
# 25099           -3.895946                0.021741        175.302493
#
# [13300 rows x 10 columns]

# %%
# plt.scatter(filtered_results.input_perturbation, filtered_results.output_perturbation)

# %%
# plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
# plt.ylim(-350, 150)
plt.scatter(x=results.input_perturbation, y=results.output_perturbation, color='black', s=10, zorder=5)  # Adjust the 's' parameter to make dots thinner
plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in PT-JPL Latent Heat Flux (W/m$^2$)")
plt.title("Comparison of Change\nin Surface Temperature\nto PT-JPL Latent Heat Flux")

plt.savefig("Comparison of Change in Surface Temperature to PT-JPL Latent Heat Flux.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to PT-JPL Latent Heat Flux.svg", format='svg', bbox_inches='tight')

plt.show()

# %%
correlation = mstats.pearsonr(
    np.array(filtered_results.input_perturbation_std).astype(np.float64), 
    np.array(filtered_results.output_perturbation_std).astype(np.float64)
)[0]

correlation
# Out:
# np.float64(0.17826859982030013)

# %%
input_variables = ["ST_C", "NDVI", "albedo", "Ta_C", "RH"]
output_variables = ["LE"]

perturbation_df, sensitivity_metrics_df = sensitivity_analysis(
    input_df=input_df,
    input_variables=input_variables,
    output_variables=output_variables,
    forward_process=process_verma_PTJPLSM_table,
    normalization_function=normalization_function
)

sensitivity_metrics_df
# Out:
# [2025-07-02 17:30:59 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 17:30:59 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# [2025-07-02 17:31:06 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 17:31:06 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-02 19:07:53 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 19:07:53 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perturbation_df = pd.concat([perturbation_df, run_results])
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:89: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   sensitivity_metrics_df = pd.concat([sensitivity_metrics_df, pd.DataFrame([[
# [2025-07-02 19:09:34 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 19:09:34 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-02 20:44:07 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 20:44:07 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /opt/homebrew/Caskroom/miniforge/base/envs/PTJPLSM/lib/python3.10/site-packages/PTJPL/vegetation_conversion/vegetation_conversion.py:45: RuntimeWarning: divide by zero encountered in log
#   LAI = rt.clip(-np.log(1 - fIPAR) * (1 / KPAR), min_LAI, max_LAI)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-02 20:46:05 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 20:46:05 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-02 23:05:27 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 23:05:27 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-02 23:12:05 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-02 23:12:05 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-03 04:51:54 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-03 04:51:54 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# [2025-07-03 04:52:01 INFO] GEOS-5 FP working directory: /Users/gregoryhalverson/data/GEOS5FP
# [2025-07-03 04:52:01 INFO] GEOS-5 FP download directory: ~/data/GEOS5FP
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: divide by zero encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fREW.py:36: RuntimeWarning: invalid value encountered in divide
#   fREW = rt.clip(rt.where(FCWP == 0, 0, SMWP / FCWP), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:28: RuntimeWarning: divide by zero encountered in divide
#   WPCH = rt.clip(rt.where(CHscalar == 0, 0, wilting_point / CHscalar), 0, 1)
# /Users/gregoryhalverson/Projects/PT-JPL-SM/PTJPLSM/partitioning/fTRM.py:30: RuntimeWarning: invalid value encountered in power
#   fTREW = rt.clip(1 - ((CR - soil_moisture) / (CR - WPCH)) ** CHscalar, 0, 1)
#   input_variable output_variable                  metric     value
# 0           ST_C              LE             correlation  0.173634
# 0           ST_C              LE                      r2  0.030149
# 0           ST_C              LE  mean_normalized_change  0.190541
# 0           NDVI              LE             correlation  0.669784
# 0           NDVI              LE                      r2  0.448611
# 0           NDVI              LE  mean_normalized_change  0.069241
# 0         albedo              LE             correlation  0.507220
# 0         albedo              LE                      r2  0.257272
# 0         albedo              LE  mean_normalized_change  0.052861
# 0           Ta_C              LE             correlation  0.214209
# 0           Ta_C              LE                      r2  0.045886
# 0           Ta_C              LE  mean_normalized_change  0.670921
# 0             RH              LE             correlation  0.312514
# 0             RH              LE                      r2  0.097665
# 0             RH              LE  mean_normalized_change  0.106697

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "LE") & (df.metric == "mean_normalized_change")]
ax = sns.barplot(x=df.input_variable, y=df.value * 100, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
plt.xlabel("Input Variable")
plt.ylabel("Average Percent Change in Output Perturbation")
plt.title("PT-JPL Latent Heat Flux Sensitivity Magnitude")
# plt.ylim(0, 160)  # Set y-axis range from 0 to 160
plt.grid(axis='y', color='lightgray', linestyle='-', linewidth=0.5)  # Add light gray horizontal gridlines only

# Add percent sign to y-axis tick labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{int(y)}%'))

plt.savefig("PT-JPL Latent Heat Flux Sensitivity Magnitude.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("PT-JPL Latent Heat Flux Sensitivity Magnitude.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/bv/410kt7f93x78j9dww00h1pz80000gn/T/ipykernel_33253/1678908124.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "LE") & (df.metric == "correlation")]
ax = sns.barplot(x=df.input_variable, y=df.value, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
# plt.ylim(0, 0.8)
plt.xlabel("Input Variable")
plt.ylabel("Correlation of Input Perturbation to Output Perturbation")
plt.title("PT-JPL Latent Heat Flux Sensitivity Correlation")
plt.grid(axis='y')  # Add horizontal gridlines

plt.savefig("PT-JPL Latent Heat Flux Sensitivity Correlation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("PT-JPL Latent Heat Flux Sensitivity Correlation.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/bv/410kt7f93x78j9dww00h1pz80000gn/T/ipykernel_33253/2265298213.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
